# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/project3/deep-text-recognition-benchmark
# Out:
# /content/drive/MyDrive/project3/deep-text-recognition-benchmark

# %%
# [None | TPS]
# [VGG | RCNN | ResNet]
# [None | BiLSTM]
# [CTC | Attn]

# !python train.py \
--train_data "./data/lmdb/train" \
--valid_data "./data/lmdb/val" \
--select_data / \
--batch_ratio 1 \
--Transformation None \
--FeatureExtraction "VGG" \
--SequenceModeling "BiLSTM" \
--Prediction "CTC" \
--input_channel 1 \
--output_channel 256 \
--hidden_size 256 \
--saved_model "./pre_trained_model/korean_g2.pth" \
--FT
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: ./data/lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    ./data/lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 1291
# num total samples of /: 1291 x 1.0 (total_data_usage_ratio) = 1291
# num samples of / per batch: 192 x 1.0 (batch_ratio) = 192
# --------------------------------------------------------------------------------
# Total_batch_size: 192 = 192
# --------------------------------------------------------------------------------
# dataset_root:    ./data/lmdb/val	 dataset: /
# sub-directory:	/.	 num samples: 122
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 32 100 20 1 256 256 1009 25 None VGG BiLSTM CTC
# loading pretrained model from ./pre_trained_model/korean_g2.pth
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=1009, bias=True)
#   )
# )
# Trainable params num :  4015729
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     lr: 1
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# exp_name: None-VGG-BiLSTM-CTC-Seed1111
# train_data: ./data/lmdb/train
# valid_data: ./data/lmdb/val
# manualSeed: 1111
# workers: 4
# batch_size: 192
# num_iter: 300000
# valInterval: 2000
# saved_model: ./pre_trained_model/korean_g2.pth
# FT: True
# adam: False
# lr: 1
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# baiduCTC: False
# select_data: ['/']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 25
# imgH: 32
# imgW: 100
# rgb: False
# character:  !"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_`abcdefghijklmnopqrstuvwxyz{|}~가각간갇갈감갑값강갖같갚갛개객걀거걱건걷걸검겁것겉게겨격겪견결겹경곁계고곡곤곧골곰곱곳공과관광괜괴굉교구국군굳굴굵굶굽궁권귀규균그극근글긁금급긋긍기긴길김깅깊까깎깐깔깜깝깥깨꺼꺾껍껏껑께껴꼬꼭꼴꼼꼽꽂꽃꽉꽤꾸꿀꿈뀌끄끈끊끌끓끔끗끝끼낌나낙낚난날낡남납낫낭낮낯낱낳내냄냉냐냥너넉널넓넘넣네넥넷녀녁년념녕노녹논놀놈농높놓놔뇌뇨누눈눕뉘뉴늄느늑는늘늙능늦늬니닐님다닥닦단닫달닭닮담답닷당닿대댁댐더덕던덜덤덥덧덩덮데델도독돈돌돕동돼되된두둑둘둠둡둥뒤뒷드득든듣들듬듭듯등디딩딪따딱딴딸땀땅때땜떠떡떤떨떻떼또똑뚜뚫뚱뛰뜨뜩뜯뜰뜻띄라락란람랍랑랗래랜램랫략량러럭런럴럼럽럿렁렇레렉렌려력련렬렵령례로록론롬롭롯료루룩룹룻뤄류륙률륭르른름릇릎리릭린림립릿마막만많말맑맘맙맛망맞맡맣매맥맨맵맺머먹먼멀멈멋멍멎메멘멩며면멸명몇모목몰몸몹못몽묘무묵묶문묻물뭄뭇뭐뭣므미민믿밀밉밌및밑바박밖반받발밝밟밤밥방밭배백뱀뱃뱉버번벌범법벗베벤벼벽변별볍병볕보복볶본볼봄봇봉뵈뵙부북분불붉붐붓붕붙뷰브블비빌빗빚빛빠빨빵빼뺨뻐뻔뻗뼈뽑뿌뿐쁘쁨사삭산살삶삼상새색샌생서석섞선설섬섭섯성세센셈셋션소속손솔솜솟송솥쇄쇠쇼수숙순술숨숫숲쉬쉽슈스슨슬슴습슷승시식신싣실싫심십싱싶싸싹쌀쌍쌓써썩썰썹쎄쏘쏟쑤쓰쓸씀씌씨씩씬씹씻아악안앉않알앓암압앗앙앞애액야약얇양얗얘어억언얹얻얼엄업없엇엉엌엎에엔엘여역연열엷염엽엿영옆예옛오옥온올옮옳옷와완왕왜왠외왼요욕용우욱운울움웃웅워원월웨웬위윗유육율으윽은을음응의이익인일읽잃임입잇있잊잎자작잔잖잘잠잡장잦재쟁저적전절젊점접젓정젖제젠젯져조족존졸좀좁종좋좌죄주죽준줄줌줍중쥐즈즉즌즐즘증지직진질짐집짓징짙짚짜짝짧째쨌쩌쩍쩐쪽쫓쭈쭉찌찍찢차착찬찮찰참창찾채책챔챙처척천철첫청체쳐초촉촌총촬최추축춘출춤춥춧충취츠측츰층치칙친칠침칭카칸칼캐캠커컨컬컴컵컷켓켜코콜콤콩쾌쿠퀴크큰클큼키킬타탁탄탈탑탓탕태택탤터턱털텅테텍텔템토톤톱통퇴투툼퉁튀튜트특튼튿틀틈티틱팀팅파팎판팔패팩팬퍼퍽페펴편펼평폐포폭표푸푹풀품풍퓨프플픔피픽필핏핑하학한할함합항해핵핸햄햇행향허헌험헤헬혀현혈협형혜호혹혼홀홍화확환활황회획횟효후훈훌훔훨휘휴흉흐흑흔흘흙흡흥흩희흰히힘
# sensitive: False
# PAD: False
# data_filtering_off: False
# Transformation: None
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 1
# output_channel: 256
# hidden_size: 256
# num_gpu: 1
# num_class: 1009
# ---------------------------------------
#
# [1/300000] Train loss: 4.06568, Valid loss: 3.68254, Elapsed_time: 0.64490
# Current_accuracy : 19.672, Current_norm_ED  : 0.48
# Best_accuracy    : 19.672, Best_norm_ED     : 0.48
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 전남여성가족재단                  |  B히'-모                    | 0.0000	False
# 빨간지붕                      | 발봉지통                      | 0.0260	False
# 칼라흑백디지털복사기                | 아화씩트                      | 0.0002	False
# 뜰안에냥                      | 돌 낭                       | 0.0400	False
# 수                         | 손                         | 0.4538	False
# --------------------------------------------------------------------------------
# [2000/300000] Train loss: 0.04396, Valid loss: 2.79239, Elapsed_time: 1034.37226
# Current_accuracy : 34.426, Current_norm_ED  : 0.61
# Best_accuracy    : 34.426, Best_norm_ED     : 0.61
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 동탄                        | 홍환                        | 0.2627	False
# 원우공구철물                    | 원우공구찰물                    | 0.8025	False
# 삼미                        | 삼미                        | 1.0000	True
# 나라부동산                     | 나관부동집                     | 0.3533	False
# 이지 동물 의료센터                | 이끼동물의로전학                  | 0.0127	False
# --------------------------------------------------------------------------------
# [4000/300000] Train loss: 0.00080, Valid loss: 2.83374, Elapsed_time: 2060.13736
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 핵밥                        | 학밥                        | 0.4987	False
# 부동산                       | 부동산                       | 0.3500	True
# 율산유치원                     | 울산유치원                     | 0.9723	False
# 임야 및  토지                  | 임아맞토지                     | 0.5283	False
# 남성컷트                      | 남성컷은                      | 0.7305	False
# --------------------------------------------------------------------------------
# [6000/300000] Train loss: 0.00009, Valid loss: 2.88841, Elapsed_time: 3083.49828
# Current_accuracy : 36.066, Current_norm_ED  : 0.62
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 애플                        | 애플                        | 0.9306	True
# 부동산                       | 부동산                       | 0.9995	True
# 반                         | 반                         | 0.9838	True
# 센스미용실                     | 센스미용실                     | 0.9946	True
# 네비게이션                     | 네비게이선                     | 0.6618	False
# --------------------------------------------------------------------------------
# [8000/300000] Train loss: 0.00006, Valid loss: 2.94436, Elapsed_time: 4101.73136
# Current_accuracy : 36.066, Current_norm_ED  : 0.62
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 만복할인마트                    | 산동팔바동                     | 0.0508	False
# 전남여성가족재단                  | 진명대생국타                    | 0.0310	False
# 열린창호                      | 열린창호                      | 0.5372	True
# 당구장                       | 당구장                       | 0.9986	True
# 털 보 네 두 부                 | 털보네두부                     | 0.7664	False
# --------------------------------------------------------------------------------
# [10000/300000] Train loss: 0.00004, Valid loss: 2.96938, Elapsed_time: 5119.77033
# Current_accuracy : 36.066, Current_norm_ED  : 0.62
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 고기덮밥잘하는집                  | 고기료밥골헤는점                  | 0.0236	False
# 삼미                        | 삼미                        | 1.0000	True
# 카페                        | 카페                        | 1.0000	True
# 공명부동산                     | 공정부중산                     | 0.3806	False
# 구구족                       | 구구족                       | 0.8538	True
# --------------------------------------------------------------------------------
# [12000/300000] Train loss: 0.00004, Valid loss: 2.99175, Elapsed_time: 6143.10449
# Current_accuracy : 36.066, Current_norm_ED  : 0.63
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 보성                        | 보성                        | 0.8020	True
# 반                         | 반                         | 0.9902	True
# 유정인테리어                    | 유정인테리어                    | 0.9886	True
# 고기덮밥잘하는집                  | 고기료밥골하는점                  | 0.0238	False
# 애니핸즈                      | 약비행주                      | 0.0784	False
# --------------------------------------------------------------------------------
# [14000/300000] Train loss: 0.00003, Valid loss: 3.00701, Elapsed_time: 7155.05986
# Current_accuracy : 36.066, Current_norm_ED  : 0.63
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 율산유치원                     | 울산유치원                     | 0.9770	False
# 밀촌                        | 밀조                        | 0.7691	False
# 보인 안마 시술원                 | 예아원x대                     | 0.0860	False
# 조은참치                      | 꼬마한                       | 0.2679	False
# 마왕족발                      | 마왕족발                      | 0.5456	True
# --------------------------------------------------------------------------------
# [16000/300000] Train loss: 0.00003, Valid loss: 3.02924, Elapsed_time: 8169.77939
# Current_accuracy : 36.066, Current_norm_ED  : 0.63
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 열린창호                      | 열린창호                      | 0.5633	True
# 동아루                       | 동아루                       | 0.9985	True
# 보성                        | 보성                        | 0.8052	True
# 미용재료                      | 미용재료                      | 0.9964	True
# 공명부동산                     | 공정부중산                     | 0.3830	False
# --------------------------------------------------------------------------------
# [18000/300000] Train loss: 0.00002, Valid loss: 3.04915, Elapsed_time: 9184.57776
# Current_accuracy : 36.066, Current_norm_ED  : 0.63
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 오솔길                       | 오습길                       | 0.9178	False
# 당구장                       | 당구장                       | 0.9989	True
# 착한분식                      | 한한회비                      | 0.2720	False
# 보성                        | 보성                        | 0.8153	True
# 빨간지붕                      | 발간지통                      | 0.8914	False
# --------------------------------------------------------------------------------
# [20000/300000] Train loss: 0.00002, Valid loss: 3.06130, Elapsed_time: 10199.94545
# Current_accuracy : 36.066, Current_norm_ED  : 0.63
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 네비게이션                     | 네비게이선                     | 0.6904	False
# 부동산                       | 부동산                       | 0.5974	True
# 뜰안에냥                      | 도나냥                       | 0.5064	False
# 디                         | 디                         | 0.8545	True
# 현명기                       | 현명기                       | 0.3895	True
# --------------------------------------------------------------------------------
# [22000/300000] Train loss: 0.00002, Valid loss: 3.07417, Elapsed_time: 11211.33043
# Current_accuracy : 36.066, Current_norm_ED  : 0.63
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 전남여성가족재단                  | 진명대생국타                    | 0.0538	False
# 의                         |                           | 0.9518	False
# 마왕족발                      | 마왕족발                      | 0.5356	True
# 현명기                       | 현명기                       | 0.3745	True
# 조이피아노                     | 조이피아노                     | 0.9992	True
# --------------------------------------------------------------------------------
# [24000/300000] Train loss: 0.00002, Valid loss: 3.11128, Elapsed_time: 12226.06759
# Current_accuracy : 36.066, Current_norm_ED  : 0.63
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 반                         | 반                         | 0.9938	True
# 약국                        | 학국                        | 0.7711	False
# 도매                        | 도매                        | 0.9318	True
# 소매                        | 초매                        | 0.5454	False
# 임대판매                      | 입대판패                      | 0.6550	False
# --------------------------------------------------------------------------------
# [26000/300000] Train loss: 0.00002, Valid loss: 3.10386, Elapsed_time: 13239.61895
# Current_accuracy : 36.066, Current_norm_ED  : 0.63
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 만복할인마트                    | 산동팔바용                     | 0.0558	False
# 강촌장어요리전문                  | 자래라삼점                     | 0.0042	False
# 디                         | 디                         | 0.8503	True
# 딱이야                       | 닭이야                       | 0.7768	False
# 모텔                        | 모델                        | 0.9964	False
# --------------------------------------------------------------------------------
# [28000/300000] Train loss: 0.00001, Valid loss: 3.12148, Elapsed_time: 14252.49466
# Current_accuracy : 36.066, Current_norm_ED  : 0.63
# Best_accuracy    : 36.885, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 임대판매                      | 입대판패                      | 0.6617	False
# 강촌장어요리전문                  | 자래라삼점                     | 0.0041	False
# 디                         | 디                         | 0.8544	True
# 반려동물 용품점                  | 전학동원 용종병                  | 0.0072	False
# 즉석                        | 옥국                        | 0.4488	False
# --------------------------------------------------------------------------------
# [30000/300000] Train loss: 0.00001, Valid loss: 3.12663, Elapsed_time: 15281.61459
# Current_accuracy : 37.705, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 초이스                       | 토이스                       | 0.9378	False
# 골드공인중개사                   | 골드 공인찌                    | 0.0418	False
# 조은참치                      | 꼬마한                       | 0.2777	False
# 서가네                       | 서가네                       | 0.9363	True
# 도매                        | 도매                        | 0.9458	True
# --------------------------------------------------------------------------------
# [32000/300000] Train loss: 0.00001, Valid loss: 3.13839, Elapsed_time: 16321.85989
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 삼강약국                      | 삼강와국                      | 0.9055	False
# 이지 동물 의료센터                | 이끼동물의로전회                  | 0.0193	False
# 하정집                       | 하정집                       | 0.9853	True
# 국향반점                      | 닭양발점                      | 0.5441	False
# 초이스                       | 토이스                       | 0.9436	False
# --------------------------------------------------------------------------------
# [34000/300000] Train loss: 0.00001, Valid loss: 3.14611, Elapsed_time: 17361.94998
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.63
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 양지이용소                     | 양지이용소                     | 0.9996	True
# 만복할인마트                    | 산동팔바용                     | 0.0672	False
# 시실로와                      | 시실로와                      | 0.8524	True
# 삼미                        | 삼미                        | 1.0000	True
# 나주시산림조합                   | 나주시산랑조밥                   | 0.1574	False
# --------------------------------------------------------------------------------
# [36000/300000] Train loss: 0.00001, Valid loss: 3.15876, Elapsed_time: 18400.91715
# Current_accuracy : 37.705, Current_norm_ED  : 0.64
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 시실로와                      | 시실로와                      | 0.8596	True
# 음악교습소                     | 음악교습소                     | 0.8450	True
# 전남경찰청 어린이집                | 생상광x영비만빛                  | 0.0087	False
# 유정인테리어                    | 유정인테리어                    | 0.9923	True
# 남성컷트                      | 남성컷은                      | 0.6118	False
# --------------------------------------------------------------------------------
# [38000/300000] Train loss: 0.00001, Valid loss: 3.16551, Elapsed_time: 19434.91862
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 모노뷰티끄                     | 모노부리교                     | 0.9287	False
# 미리네칼국수                    | 미리네칼구스                    | 0.2399	False
# 털 보 네 두 부                 | 털보네두부                     | 0.8052	False
# 즉석                        | 옥국                        | 0.4935	False
# 맞춤양복                      | 맛춤양복                      | 0.4058	False
# --------------------------------------------------------------------------------
# [40000/300000] Train loss: 0.00001, Valid loss: 3.16571, Elapsed_time: 20486.86263
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 전남경찰청 어린이집                | 생상광x영비만빛                  | 0.0090	False
# 명성목형                      | 명성복형                      | 0.8807	False
# 송헤어라인                     | 송헤어라인                     | 0.8512	True
# 동아루                       | 동아루                       | 0.9976	True
# 핵밥                        | 학밥                        | 0.5052	False
# --------------------------------------------------------------------------------
# [42000/300000] Train loss: 0.00001, Valid loss: 3.18038, Elapsed_time: 21524.69010
# Current_accuracy : 37.705, Current_norm_ED  : 0.64
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 밀촌                        | 밀조                        | 0.7813	False
# 본                         | x레                        | 0.2535	False
# 부동산                       | 부동산                       | 0.6572	True
# 자르고                       | 자르고                       | 0.8810	True
# 삼미                        | 삼미                        | 1.0000	True
# --------------------------------------------------------------------------------
# [44000/300000] Train loss: 0.00001, Valid loss: 3.17596, Elapsed_time: 22555.07191
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 삼강약국                      | 삼강와국                      | 0.9036	False
# 오복식당                      | 오복식당                      | 0.9020	True
# 도매                        | 도매                        | 0.9489	True
# 카메라사랑                     | 카메라시랑                     | 0.2790	False
# 시실로와                      | 시실로와                      | 0.8560	True
# --------------------------------------------------------------------------------
# [46000/300000] Train loss: 0.00001, Valid loss: 3.18939, Elapsed_time: 23572.07083
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 서가네                       | 서가네                       | 0.9524	True
# 조은참치                      | 꼬파한                       | 0.3147	False
# 멍주르                       | 얼루드                       | 0.2946	False
# 모텔                        | 모델                        | 0.9966	False
# 오솔길                       | 오습길                       | 0.9410	False
# --------------------------------------------------------------------------------
# [48000/300000] Train loss: 0.00001, Valid loss: 3.19571, Elapsed_time: 24594.83688
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 애견미용                      | 애견미용                      | 0.8483	True
# 전남여성가족재단                  | 진명대생국타                    | 0.0610	False
# 송헤어라인                     | 송헤어라인                     | 0.8538	True
# 육가촌                       | 육가촌                       | 0.9998	True
# 동아루                       | 동아루                       | 0.9989	True
# --------------------------------------------------------------------------------
# [50000/300000] Train loss: 0.00001, Valid loss: 3.18322, Elapsed_time: 25671.50579
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 임야 및  토지                  | 임아맞토지                     | 0.4361	False
# 딱이야                       | 닭이야                       | 0.7797	False
# 삼성                        | 삼성                        | 1.0000	True
# 복사골뼈다귀                    | 복시골디다구                    | 0.0627	False
# 도매                        | 도매                        | 0.9540	True
# --------------------------------------------------------------------------------
# [52000/300000] Train loss: 0.00001, Valid loss: 3.20248, Elapsed_time: 26898.22046
# Current_accuracy : 37.705, Current_norm_ED  : 0.64
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 유정인테리어                    | 유정인테리어                    | 0.9931	True
# 의                         |                           | 0.9375	False
# 그리다                       | 고리다                       | 0.8739	False
# 하정집                       | 하정집                       | 0.9869	True
# 디                         | 디                         | 0.8670	True
# --------------------------------------------------------------------------------
# [54000/300000] Train loss: 0.00001, Valid loss: 3.19531, Elapsed_time: 28067.66322
# Current_accuracy : 37.705, Current_norm_ED  : 0.64
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 맥주                        | 맥주                        | 0.9240	True
# 뜰안에냥                      | 도나냥                       | 0.5652	False
# 시실로와                      | 시실로와                      | 0.8626	True
# 자르고                       | 자르고                       | 0.8768	True
# 잘난푸드                      | 발한구스                      | 0.6822	False
# --------------------------------------------------------------------------------
# [56000/300000] Train loss: 0.00001, Valid loss: 3.20129, Elapsed_time: 29247.94829
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 나래                        | 노래                        | 0.2307	False
# 이주현                       | 이주현                       | 0.9993	True
# 착한분식                      | 한한회비                      | 0.3063	False
# 명성목형                      | 명성복형                      | 0.8710	False
# 율산유치원                     | 울산유치원                     | 0.9779	False
# --------------------------------------------------------------------------------
# [58000/300000] Train loss: 0.00001, Valid loss: 3.21730, Elapsed_time: 30425.44543
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 카페                        | 카페                        | 0.9999	True
# 대박국수                      | 대박구수                      | 0.8668	False
# 약국                        | 학국                        | 0.8559	False
# 모텔                        | 모델                        | 0.9972	False
# 복권판매점                     | 복건판매점                     | 0.7195	False
# --------------------------------------------------------------------------------
# [60000/300000] Train loss: 0.00001, Valid loss: 3.21525, Elapsed_time: 31628.28299
# Current_accuracy : 37.705, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 맞춤양복                      | 맛춤양복                      | 0.3902	False
# 착한분식                      | 한한회비                      | 0.3024	False
# 임야 및  토지                  | 임아맞토지                     | 0.4141	False
# 아카데미                      | 아라테메                      | 0.3599	False
# 애견미용                      | 애견미용                      | 0.8541	True
# --------------------------------------------------------------------------------
# [62000/300000] Train loss: 0.00001, Valid loss: 3.23193, Elapsed_time: 32872.13849
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 도매                        | 도매                        | 0.9560	True
# 반                         | 반                         | 0.9957	True
# 마포종점                      | 마도종점                      | 0.1260	False
# 나주렌트카                     | 나구린트가                     | 0.6010	False
# 동탄시티병원                    | 동단지인형인                    | 0.1028	False
# --------------------------------------------------------------------------------
# [64000/300000] Train loss: 0.00001, Valid loss: 3.23328, Elapsed_time: 34183.19616
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 마왕족발                      | 마왕족발                      | 0.5274	True
# 미용재료                      | 미용재료                      | 0.9980	True
# 임대판매                      | 입대판패                      | 0.6320	False
# 대박국수                      | 대박구수                      | 0.8623	False
# 애플                        | 애플                        | 0.9162	True
# --------------------------------------------------------------------------------
# [66000/300000] Train loss: 0.00001, Valid loss: 3.23971, Elapsed_time: 35492.56783
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 보인 안마 시술원                 | 예아원x대                     | 0.1325	False
# 오복식당                      | 오복식당                      | 0.9062	True
# 나라부동산                     | 나진부동집                     | 0.4400	False
# 초량상회                      | 초량상회                      | 0.7443	True
# 국향반점                      | 닭양발점                      | 0.5615	False
# --------------------------------------------------------------------------------
# [68000/300000] Train loss: 0.00001, Valid loss: 3.25209, Elapsed_time: 36756.33662
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 삼성                        | 삼성                        | 1.0000	True
# 오솔길                       | 오습길                       | 0.9507	False
# 남성컷트                      | 남성컷은                      | 0.5604	False
# 동탄                        | 중환                        | 0.2782	False
# 설치                        | 설치                        | 0.9641	True
# --------------------------------------------------------------------------------
# [70000/300000] Train loss: 0.00001, Valid loss: 3.24858, Elapsed_time: 37921.55493
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 딱이야                       | 닭이야                       | 0.7701	False
# 문고                        | 문코                        | 0.3947	False
# 이주현                       | 이주현                       | 0.9993	True
# 가스                        | 가스                        | 1.0000	True
# 부동산                       | 부동산                       | 0.9999	True
# --------------------------------------------------------------------------------
# [72000/300000] Train loss: 0.00001, Valid loss: 3.25303, Elapsed_time: 39091.66182
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 반려동물 용품점                  | 한학동원 용통병                  | 0.0102	False
# 현명기                       | 현명기                       | 0.3307	True
# 강촌장어요리전문                  | 자래라삼점                     | 0.0070	False
# 닭백숙                       | 닭백숙                       | 0.9964	True
# 복권판매점                     | 복건판매점                     | 0.7220	False
# --------------------------------------------------------------------------------
# [74000/300000] Train loss: 0.00001, Valid loss: 3.25936, Elapsed_time: 40302.43470
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 하정집                       | 하정집                       | 0.9890	True
# 이주현                       | 이주현                       | 0.9993	True
# 수                         | 스                         | 0.9777	False
# 카츠만                       | 카술모                       | 0.1954	False
# 카메라사랑                     | 카메라시랑                     | 0.3328	False
# --------------------------------------------------------------------------------
# [76000/300000] Train loss: 0.00001, Valid loss: 3.26319, Elapsed_time: 41608.96038
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 락희약국                      | 탁학약국                      | 0.7617	False
# 피부과                       | 피부파                       | 0.4997	False
# 복권판매점                     | 복건판매점                     | 0.7330	False
# 미리네칼국수                    | 미리네칼구스                    | 0.2684	False
# 그리다                       | 고리다                       | 0.8714	False
# --------------------------------------------------------------------------------
# [78000/300000] Train loss: 0.00000, Valid loss: 3.26290, Elapsed_time: 42781.97472
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 대박국수                      | 대박구수                      | 0.8652	False
# 열린창호                      | 열린창호                      | 0.5636	True
# 불고기                       | 물고기                       | 0.3941	False
# 디저트 수                     | 디지트수                      | 0.5250	False
# 칼라흑백디지털복사기                | 제화어피로테어                   | 0.0471	False
# --------------------------------------------------------------------------------
# [80000/300000] Train loss: 0.00000, Valid loss: 3.27437, Elapsed_time: 43973.87118
# Current_accuracy : 36.885, Current_norm_ED  : 0.63
# Best_accuracy    : 37.705, Best_norm_ED     : 0.64
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 맞춤양복                      | 맛춤양복                      | 0.3944	False
# 복권판매점                     | 복건판매점                     | 0.7272	False
# 자르고                       | 자르고                       | 0.8880	True
# 동탄                        | 중환                        | 0.3032	False
# 현명기                       | 현명기                       | 0.3462	True
# --------------------------------------------------------------------------------
